# %%
from google.colab import drive
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df = pd.read_csv ('/content/gdrive/MyDrive/L1--6-28-2022/iris.csv'); header=None
df.columns = ['Sepal.Length', 'Sepal.Width', 'Pepal.Length', 'Petal.Width', 'Class']
df
# Out:
#      Sepal.Length  Sepal.Width  Pepal.Length  Petal.Width           Class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# !top
# Out:
# =top - 19:33:03 up 6 min,  0 users,  load average: 0.89, 0.34, 0.15
# Tasks:  19 total,   1 running,  17 sleeping,   0 stopped,   1 zombie
# %Cpu(s):  6.8 us,  3.2 sy,  0.0 ni, 87.9 id,  2.1 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13298580 total, 10124044 free,   932452 used,  2242084 buff/cache
# KiB Swap:        0 total,        0 free,        0 used. 12158408 avail Mem
#
#     PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#     270 root      20   0  710124 335532  32112 S 186.7  2.5   0:17.67 node
#       7 root      20   0  339812  49740  32548 S   6.7  0.4   0:00.60 node
#      72 root      20   0  580276 139704  47084 S   6.7  1.1   0:02.71 python3
#       1 root      20   0     992      4      0 S   0.0  0.0   0:00.45 docker-i+
#      17 root      20   0   35892   4904   3812 S   0.0  0.0   0:00.48 tail
#      27 root      20   0       0      0      0 Z   0.0  0.0   0:04.20 python3
# ...
